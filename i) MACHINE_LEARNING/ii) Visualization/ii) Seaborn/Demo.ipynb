# %%
import seaborn as sns
df=sns.load_dataset('tips')  # this dataset tips is available for study puropose. tip is the o/p column
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#correlation corr()
#Correlation is a way to measure how strongly two variables(columns) are related to each other.
#In machine learning, it helps us understand which features (inputs) are connected and how they affect the target (output).
#For feature selection,we use a method called correlation.By using this we can understand which column is important or not.
#the highest vale of corerelation is 1 and the lowest will be 0 or negative values.

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#if we find the correlation, we get only the correlation between numerical columns.
#here we can't find the object correlation.
#For this we use chi-sqaure test

# %%
#chi-square test
#The Chi-Square Test is a statistical test used to check if there is a significant relationship between two categorical(object)  variables

#How It Works:
# * Compares observed frequencies (what you see in your data) with expected frequencies (what you would expect if variables were independent).

# * If the difference is big, the relationship is likely significant.

# %%
# in the above correlation table, tip is the o/p column
# if we consider correlation b/w tip and two other columns(total_bill and size), corerelation between tip and total_bill is high compared to tip and size.
# so total_bill will influence more compared to the size
#so if total_bill increses the tip will increases

# %%
# heat-map
#we can graphically plot the correation by using heat-map

sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
#joint plot

#it is similar to scatter plot..
#We can draw only between numerical columns
# But it is more advanced,so we can draw regression line also

# %%
#joinplot used for numerical columns

sns.jointplot(x='tip',y='total_bill',data=df)

# %%
#here there is an extra histogram is formed.
#for drawing the regression line use kind='reg'

sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
#in heaxagon shape
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

#the dark coloured heaxagon portion is tip will be high

# %%
#tip and size  regression
sns.jointplot(x='tip',y='size',data=df,kind='reg')

# %%
#tip and size  hexagon
sns.jointplot(x='tip',y='size',data=df,kind='hex')

# %%
#total_bill and size  regression
sns.jointplot(x='tip',y='size',data=df,kind='reg')

# %%
#total_bill and size  hexagon
sns.jointplot(x='tip',y='size',data=df,kind='hex')

# %%
#pair plot

#we can plot all the join plots in a single plot.for that we use pair plot

#in above eg we can draw 3 join plots

# tip  --- totalbill
# tip  --- size
# size --- totalbill


sns.pairplot(df)

# %%
# if the features is same ie, tip -- tip, size--size, totalbill -- totalbill the piar plot will be in histogram

sns.pairplot(df,kind='reg')

# sns.pairplot(df,kind='hex') in pairplot only reg will support.

# %%
# dtype is object (categorical)
#____________________________

# %%
df.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df.value_counts('smoker')
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df.value_counts('day')
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.value_counts('time')
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
#object

#hue ==> for comparison

# the hue parameter is used to represent a categorical variable by assigning different colors to different categories. 
# It allows you to differentiate data points in a plot by color, 
# helping to visualize the relationship between data points more clearly based on a particular category.


sns.pairplot(df,hue='time')

# %%
sns.pairplot(df,hue='day')

# %%
#________________________count_plot________________________#
#the plot will be in bar

#if there is an object dtype, we first find the count then visualise it
#but using the count plot we can directly visualise it and find the count

sns.countplot(x='day',data=df,color='r')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time',data=df,color='g')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
#if we use y= the graph will be in y axis
sns.countplot(y='sex',data=df,color='b')
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
#we can use hue also

sns.countplot(x='smoker',data=df,color='c',hue='sex')
# Out:
# C:\Users\Vandana Udayakumar\AppData\Local\Temp\ipykernel_13972\564655925.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:c'` for the same effect.
#
#   sns.countplot(x='smoker',data=df,color='c',hue='sex')
# <Axes: xlabel='smoker', ylabel='count'>

# %%
#bar plot
#we;ve to define x,y,data

sns.barplot(x='total_bill',y='day',data=df)
#the black line is the representation of average
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
#______________________Box plot()__________________________#

#used for identify outliers (the wrong datas in the dataset is called outliers)

sns.boxplot(y='total_bill',data=df)
#here the value above 40 is outlier
#outliers will be in both upper and lower postion
# Out:
# <Axes: ylabel='total_bill'>

# %%
df['total_bill'].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
sns.boxplot(y='tip',data=df)
#here the value above 6 is outlier
# Out:
# <Axes: ylabel='tip'>

# %%
#to identify outliers we use boxplot.

#the line in the lower part is the minimum
#the first line in the box is called 25 percentle(Q1)
#the second (center) line in the box is called 50 percentle(Q2)
##the third line in the box is called 75 percentle(Q3)
#the line in the upper part is the maximum

# %%
#3,7,1,1,8,4,6,9

#1) Sort the datas in ascending order 1,1,3,4,6,7,8,9
#2) Calculate the median it is even so divide it into two 1,1,3,4  6,7,8,9   median=(4+6)/2=5
# this median is the Q2. ie, Q2 = 5
# for Q1, we've to find the median of first part (1,1,3,4) ie, median= (1+3)/2=2 ===> Q1 = 2
# for Q3, we've to find the median of second part (6,7,8,9) ie, median= (7+8)/2=7.5 ===> Q3 = 7.5

#3) Find IQR (Inter Quartile Range) = Q3-Q1
#ie, IQR = Q3 - Q1 = 7.5-2 = 5.5

#4) Calculate top outliers
# Top_outliers = (Q3+(1.5*IQR)) = (7.5+(1.5*5.5)) = 15.75
#here the values above 15.75 is consider as the outliers

#5) Calculate bottom outliers
# Bottom_outliers = (Q1-(1.5*IQR)) = (2-(1.5*5.5)) = -6.25
#here the values below -6.25 is consider as the outliers

# %%
# Implement the above concept into a code.

import numpy as np
Q1=np.percentile(df['total_bill'],25,method='midpoint')  #Q1
Q3=np.percentile(df['total_bill'],75,method='midpoint')  #Q3
IQR = Q3 - Q1
print(IQR)
# Out:
# 10.849999999999998

# %%
upper = Q3+1.5*IQR
upper_array = np.array(df['total_bill'] >= upper) 
print('Upper_Bound',upper)
print(upper_array)
print(upper_array.sum())
# Out:
# Upper_Bound 40.449999999999996
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False  True
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False  True False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False  True False
# ...

# %%
#Below Lower Bound

lower = Q1-1.5*IQR
lower_array = np.array(df['total_bill'] <= lower) 
print('Lower_Bound',lower)
print(lower_array)
print(lower_array.sum())
# Out:
# Lower_Bound -2.9499999999999993
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
# ...

# %%
# Removing Oultier funtion( top outlier)
import matplotlib.pyplot as plt
def removal_box_plot(df, column, threshold): #arguments
    sns.boxplot(df[column]) #df['total_bill]  #sns.boxplot(df['toatl_bill])
    plt.title(f'Original Box Plot of {column}')  #40
    plt.show()
    removed_outliers = df[df[column] <= threshold]  #

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers


threshold_value = 40

no_outliers = removal_box_plot(df, 'total_bill', threshold_value)  #()
