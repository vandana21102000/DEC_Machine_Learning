# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#bar chart
x=[1,2,3,4,5,6,7,8]
y=[4,3,6,5,8,2,9,7]

plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
country=['uk','canada','india','australia','germany']
trop_count=[1,7,8,5,4]
plt.bar(country,trop_count,color='g')
plt.xlabel("Country_name")
plt.ylabel("Trophy_count")
plt.title('Garap_1')
# Out:
# Text(0.5, 1.0, 'Garap_1')

# %%
#For getting horizontally

country=['uk','canada','india','australia','germany']
trop_count=[1,7,8,5,4]
plt.barh(country,trop_count,color='g')
# Out:
# <BarContainer object of 5 artists>
